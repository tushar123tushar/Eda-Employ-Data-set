# %%
print("hell")
# Out:
# hell

# %%
import pandas as pd

# %%
data = pd.read_csv('Employee 1000x.csv')

# %%
data.head()
# Out:
#    Index First Name Last Name     Sex                        Email  \
# 0      1       Sara   Mcguire  Female           tsharp@example.net
# 1      2     Alisha    Hebert    Male   vincentgarrett@example.net
# 2      3  Gwendolyn  Sheppard    Male  mercadojonathan@example.com
# 3      4   Kristine    Mccann  Female        lindsay55@example.com
# 4      5      Bobby   Pittman  Female    blevinsmorgan@example.com
#
#                    Phone Date of birth                          Job Title
# 0     (971)643-6089x9160      17-08-21              Editor, commissioning
# 1  +1-114-355-1841x78347      28-06-69                 Broadcast engineer
# 2             9017807728      25-09-15                   Industrial buyer
# 3  +1-607-333-9911x59088      27-07-78              Multimedia specialist
# 4             3739847538      17-11-89  Planning and development surveyor

# %%
#checking NaN value Or Not 
import seaborn as sns

# %%
sns.heatmap(data.isnull()  , yticklabels=False)
# Out:
# <Axes: >

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          10000 non-null  int64
#  1   First Name     10000 non-null  object
#  2   Last Name      10000 non-null  object
#  3   Sex            10000 non-null  object
#  4   Email          10000 non-null  object
#  5   Phone          10000 non-null  object
#  6   Date of birth  10000 non-null  object
#  7   Job Title      10000 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 625.1+ KB

# %%
data.drop('Index' , axis=1 , inplace=True)

# %%
data
# Out:
#      First Name  Last Name     Sex                        Email  \
# 0          Sara    Mcguire  Female           tsharp@example.net
# 1        Alisha     Hebert    Male   vincentgarrett@example.net
# 2     Gwendolyn   Sheppard    Male  mercadojonathan@example.com
# 3      Kristine     Mccann  Female        lindsay55@example.com
# 4         Bobby    Pittman  Female    blevinsmorgan@example.com
# ...         ...        ...     ...                          ...
# 9995       Tina    Sherman    Male  bartlettcolleen@example.org
# 9996       Earl   Jennings  Female     andreabenton@example.com
# 9997      Ellen  Dominguez  Female    michaelayoder@example.net
# 9998       Emma      Clark    Male      pstrickland@example.com
# 9999    Katrina   Schwartz  Female         andres56@example.org
#
#                        Phone Date of birth                          Job Title
# 0         (971)643-6089x9160      17-08-21              Editor, commissioning
# ...

# %%
data[data['First Name'] == 'Sara'].count()
# Out:
# First Name       18
# Last Name        18
# Sex              18
# Email            18
# Phone            18
# Date of birth    18
# Job Title        18
# dtype: int64

# %%
data.isnull().sum()
# Out:
# First Name       0
# Last Name        0
# Sex              0
# Email            0
# Phone            0
# Date of birth    0
# Job Title        0
# dtype: int64

# %%
data
# Out:
#      First Name  Last Name     Sex                        Email  \
# 0          Sara    Mcguire  Female           tsharp@example.net
# 1        Alisha     Hebert    Male   vincentgarrett@example.net
# 2     Gwendolyn   Sheppard    Male  mercadojonathan@example.com
# 3      Kristine     Mccann  Female        lindsay55@example.com
# 4         Bobby    Pittman  Female    blevinsmorgan@example.com
# ...         ...        ...     ...                          ...
# 9995       Tina    Sherman    Male  bartlettcolleen@example.org
# 9996       Earl   Jennings  Female     andreabenton@example.com
# 9997      Ellen  Dominguez  Female    michaelayoder@example.net
# 9998       Emma      Clark    Male      pstrickland@example.com
# 9999    Katrina   Schwartz  Female         andres56@example.org
#
#                        Phone Date of birth                          Job Title
# 0         (971)643-6089x9160      17-08-21              Editor, commissioning
# ...
